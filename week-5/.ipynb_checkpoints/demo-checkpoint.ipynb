# %%
# %pip install rise

# %%
# Cell 1 (Slide)
from IPython.display import Markdown
Markdown("# Flask Web Platform Overview")
# Out:
# # Flask Web Platform Overview

# %%
# Cell 2 (Fragment)
from diagrams import Diagram, Cluster
from diagrams.azure.network import ApplicationGateway
from diagrams.azure.compute import VM
with Diagram("Simple Azure Diagram", show=False, filename="simple_azure"):
    lb = ApplicationGateway("App Gateway")
    vm = VM("Flask App")
    lb >> vm
from IPython.display import Image
Image(filename="simple_azure.png")

# %%
# Cell 3 (Slide)
from tabulate import tabulate
data = [["Layer", "Control"], ["App", "VM"], ["Network", "App Gateway"]]
Markdown(tabulate(data, headers="firstrow", tablefmt="fancy_grid"))
# Out:
# ╒═════════╤═════════════╕
# │ Layer   │ Control     │
# ╞═════════╪═════════════╡
# │ App     │ VM          │
# ├─────────┼─────────────┤
# │ Network │ App Gateway │
# ╘═════════╧═════════════╛
